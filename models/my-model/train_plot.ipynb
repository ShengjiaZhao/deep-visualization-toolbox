# %%
from train_plot import *

# %%
import matplotlib
matplotlib.use('Agg')
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
log = extract_info('output/test_log')

# %%
plt.plot(log['iter'], running_avg(log['accuracy']))
